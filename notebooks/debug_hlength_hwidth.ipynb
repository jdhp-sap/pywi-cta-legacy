# %%
#%matplotlib notebook
# %matplotlib inline

import matplotlib
matplotlib.rcParams['figure.figsize'] = (12, 9)

import scipy
import scipy.stats
import math
import numpy as np
import pandas as pd

#import ipywidgets
#from ipywidgets import interact

#import sys
#sys.path.append("/Users/jdecock/git/pub/jdhp-sap/sap-cta-data-pipeline/utils/")
#import common_functions as common
# Out:
# /Users/jdecock/anaconda/envs/cta/lib/python3.5/site-packages/PIL/Image.py:85: RuntimeWarning: The _imaging extension was built for another  version of Pillow or PIL
#   warnings.warn(str(v), RuntimeWarning)
# /Users/jdecock/anaconda/envs/cta/lib/python3.5/site-packages/PIL/Image.py:85: RuntimeWarning: The _imaging extension was built for another  version of Pillow or PIL
#   warnings.warn(str(v), RuntimeWarning)
# /Users/jdecock/anaconda/envs/cta/lib/python3.5/site-packages/pytz/__init__.py:29: UserWarning: Module argparse was already imported from /Users/jdecock/anaconda/envs/cta/lib/python3.5/argparse.py, but /Users/jdecock/.local/lib/python3.5/site-packages/argparse-1.1-py3.5.egg is being added to sys.path
#   from pkg_resources import resource_stream

# %% [markdown]
# ## Debug

# %%
CSV_FILE_PATH = "xps/2017_02_20/2017_02_20.csv"
TAILCUT_LABEL = "Tailcut-5-10-kill"
WAVELET_LABEL = "Wavelets-n4-K-k-C1-s3-m3-kill"
PART = 0       # 0 for gamma, 1 for protons
MIN_NPE = 0    # cut on SUM_PE_CLEANED_IMAGE

df = pd.read_csv(CSV_FILE_PATH)

ref = df[df.Type == 'Ref']
ref = ref[ref.Part == PART]

tc = df[df.Type == TAILCUT_LABEL]
tc = tc[tc.Part == PART]
tc = tc[tc.peSum >= MIN_NPE]

wt = df[df.Type == WAVELET_LABEL]
wt = wt[wt.Part == PART]
wt = wt[wt.peSum >= MIN_NPE]

# %%
tc[tc.hLength == 0].loc[:,['Id','hLength','hWidth','nPix']]
# Out:
#               Id  hLength  hWidth  nPix
# 29899   187809_1      0.0     0.0   1.0
# 30053   332600_1      0.0     0.0   1.0
# 30309   122408_2      0.0     0.0   1.0
# 30409   227905_2      0.0     0.0   1.0
# 30487   311400_2      0.0     0.0   1.0
# 30522   334600_2      0.0     0.0   1.0
# 30677   483105_2      0.0     NaN   1.0
# 30720    72605_2      0.0     0.0   1.0
# 30773   103604_3      0.0     0.0   1.0
# 30826   155601_3      0.0     0.0   1.0
# 30827   155605_3      0.0     0.0   1.0
# 30859   190600_3      0.0     0.0   1.0
# 30875   203309_3      0.0     0.0   1.0
# 31012   342002_3      0.0     0.0   1.0
# 31398   257607_4      0.0     0.0   1.0
# 31428   290205_4      0.0     0.0   1.0
# 31547   395203_4      0.0     0.0   1.0
# 31719   103608_5      0.0     0.0   1.0
# 31765   152501_5      0.0     0.0   1.0
# 31937    32606_5      0.0     0.0   1.0
# 32184     6305_6      0.0     NaN   1.0
# 32295   205903_6      0.0     0.0   1.0
# ...

# %%
wt[wt.hLength == 0].loc[:,['Id','hLength','hWidth','nPix']]
# Out:
#               Id  hLength  hWidth  nPix
# 44702     4203_1      0.0     0.0   1.0
# 44914   300901_1      0.0     0.0   1.0
# 45093   471900_1      0.0     0.0   1.0
# 45135    61000_1      0.0     NaN   1.0
# 45326   245407_2      0.0     0.0   1.0
# 45465   375201_2      0.0     0.0   1.0
# 45673   103606_3      0.0     0.0   1.0
# 45774   203309_3      0.0     0.0   1.0
# 45933   359800_3      0.0     0.0   1.0
# 45969   388407_3      0.0     0.0   1.0
# 46064   482204_3      0.0     0.0   1.0
# 46748   253903_5      0.0     0.0   1.0
# 46852   338402_5      0.0     0.0   1.0
# 46901   383601_5      0.0     0.0   1.0
# 46976   471909_5      0.0     0.0   1.0
# 47058    84805_5      0.0     0.0   1.0
# 47111   129401_6      0.0     0.0   1.0
# 47133   141006_6      0.0     0.0   1.0
# 47290   301709_6      0.0     0.0   1.0
# 47389   387902_6      0.0     0.0   1.0
# 47396   390405_6      0.0     0.0   1.0
# 47525   499108_6      0.0     NaN   1.0
# ...

# %%
tc[tc.hWidth == 0].loc[:,['Id','hLength','hWidth','nPix']]
# Out:
#               Id       hLength  hWidth  nPix
# 29806     6500_1  3.540013e-03     0.0   2.0
# 29837   127309_1  3.541641e-03     0.0   2.0
# 29850   132701_1  5.699994e-03     0.0   3.0
# 29863   149201_1  4.854579e-03     0.0   3.0
# 29867   156005_1  7.342835e-03     0.0   4.0
# 29869   157409_1  4.135500e-03     0.0   2.0
# 29884   180803_1  3.049044e-03     0.0   2.0
# 29899   187809_1  0.000000e+00     0.0   1.0
# 29927   216502_1  3.253432e-03     0.0   2.0
# 29959   243505_1  5.549467e-03     0.0   3.0
# 30053   332600_1  0.000000e+00     0.0   1.0
# 30060   334706_1  3.535070e-03     0.0   2.0
# 30100   376702_1  5.475491e-03     0.0   3.0
# 30121   393203_1  3.371446e-03     0.0   2.0
# 30179   454801_1  3.467681e-03     0.0   2.0
# 30186   460804_1  3.199130e-03     0.0   2.0
# 30190   469900_1  3.511983e-03     0.0   2.0
# 30233    55908_1  6.386916e-03     0.0   4.0
# 30234    56203_1  5.434480e-03     0.0   3.0
# 30236    61000_1  1.472550e-09     0.0   1.0
# ...

# %%
wt[wt.hWidth == 0].loc[:,['Id','hLength','hWidth','nPix']]
# Out:
#               Id       hLength  hWidth  nPix
# 44702     4203_1  0.000000e+00     0.0   1.0
# 44914   300901_1  0.000000e+00     0.0   1.0
# 45088   466006_1  7.507962e-03     0.0   4.0
# 45093   471900_1  0.000000e+00     0.0   1.0
# 45326   245407_2  0.000000e+00     0.0   1.0
# 45346   270505_2  4.860220e-03     0.0   3.0
# 45465   375201_2  0.000000e+00     0.0   1.0
# 45536    45302_2  2.319868e-03     0.0   2.0
# 45650    94908_2  6.585445e-10     0.0   1.0
# 45673   103606_3  0.000000e+00     0.0   1.0
# 45758   190600_3  3.539879e-03     0.0   2.0
# 45774   203309_3  0.000000e+00     0.0   1.0
# 45789   217809_3  3.282740e-03     0.0   2.0
# 45836   270508_3  5.220221e-03     0.0   4.0
# 45911   342002_3  5.463645e-03     0.0   3.0
# 45933   359800_3  0.000000e+00     0.0   1.0
# 45969   388407_3  0.000000e+00     0.0   1.0
# 46064   482204_3  0.000000e+00     0.0   1.0
# 46135    99503_3  1.394686e-03     0.0   2.0
# 46303   261903_4  3.563882e-03     0.0   2.0
# ...

# %% [markdown]
# ## Conclusion

# %% [markdown]
# Images with hLength = 0 are images with only one pixels $\neq$ 0 after cleaning.
#
# Images with hWidth = 0 are images with less than 4 pixels $\neq$ 0 after cleaning (most often only one pixel is remaining).
#
# See GUI with above images.
